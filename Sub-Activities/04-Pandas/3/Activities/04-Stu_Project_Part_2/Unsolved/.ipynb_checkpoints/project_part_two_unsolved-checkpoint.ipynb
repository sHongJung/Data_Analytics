# %%
# Dependencies
import pandas as pd
import os

# %%
# load CSV
csv_path = os.path.join('..', 'Resources', '2016-FCC-New-Coders-Survey-Data.csv')

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
bootcamp_df = pd.read_csv(csv_path)
bootcamp_df.head()
# Out:
# C:\Users\KenJ\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 0                NaN             NaN       ...                     NaN
# 1                NaN             NaN       ...                     NaN
# 2                NaN             NaN       ...                     NaN
# 3                NaN             NaN       ...                     NaN
# 4                NaN             NaN       ...                     NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
bootcamp_df = bootcamp_df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
bootcamp_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation           ...             \
# 0             NaN  between 100,000 and 1 million           ...
# 1             NaN  between 100,000 and 1 million           ...
# 2             NaN            more than 1 million           ...
# 3             NaN            more than 1 million           ...
# 4             NaN  between 100,000 and 1 million           ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
bootcamp_df = bootcamp_df.replace([0.0, 1.0], ["No", "Yes"])
bootcamp_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation           ...             \
# 0            NaN  between 100,000 and 1 million           ...
# 1            NaN  between 100,000 and 1 million           ...
# 2            NaN            more than 1 million           ...
# 3            NaN            more than 1 million           ...
# 4            NaN  between 100,000 and 1 million           ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No            30  32000.0
# 1  Employed for wages    male         NaN            30  15000.0
# 2  Employed for wages    male         NaN            20  48000.0
# 3  Employed for wages  female         NaN            20  43000.0
# 4  Employed for wages  female         NaN            25   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
bootcamp_df = bootcamp_df.loc[bootcamp_df["AttendedBootcamp"] == "Yes"]
bootcamp_df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation     ...      \
# 93             NaN  between 100,000 and 1 million     ...
# 97             NaN            more than 1 million     ...
# 130              3              less than 100,000     ...
# 159            NaN  between 100,000 and 1 million     ...
# 188            NaN  between 100,000 and 1 million     ...
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN
#
# [5 rows x 21 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
grouped_bootcamp = bootcamp_df.groupby('BootcampName')
grouped_bootcamp.head()
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# 206    36.0              Yes            Yes                   No
# 209    25.0              Yes            Yes                   No
# 236    52.0              Yes            Yes                  Yes
# 272    38.0              Yes            Yes                  Yes
# 273    35.0              Yes            Yes                  Yes
# 285    23.0              Yes            Yes                  Yes
# 315    31.0              Yes            Yes                   No
# 316    22.0              Yes            Yes                   No
# 328    30.0              Yes             No                  NaN
# 426    30.0              Yes            Yes                   No
# 435    26.0              Yes            Yes                   No
# 449    38.0              Yes            Yes                   No
# 465    40.0              Yes             No                  NaN
# 470    45.0              Yes             No                  NaN
# 478    37.0              Yes             No                  NaN
# 481    27.0              Yes            Yes                   No
# 488    25.0              Yes             No                  NaN
# 505    28.0              Yes            Yes                  Yes
# 510    33.0              Yes             No                  NaN
# 522    33.0              Yes            Yes                   No
# 525    31.0              Yes             No                  NaN
# 533    20.0              Yes             No                  NaN
# 543    27.0              Yes            Yes                  Yes
# 549    34.0              Yes             No                  NaN
# 608    34.0              Yes            NaN                  NaN
# ...     ...              ...            ...                  ...
# 14085   NaN              Yes            Yes                  Yes
# 14090  25.0              Yes            Yes                  Yes
# 14096   NaN              Yes            Yes                  Yes
# 14102  21.0              Yes            Yes                  Yes
# 14106   NaN              Yes            Yes                  Yes
# 14107   NaN              Yes            Yes                  Yes
# 14109   NaN              Yes            Yes                  Yes
# 14110   NaN              Yes            Yes                  Yes
# 14111   NaN              Yes            Yes                  Yes
# 14112   NaN              Yes            Yes                  Yes
# 14114  27.0              Yes            Yes                  Yes
# 14115   NaN              Yes            Yes                  Yes
# 14275  30.0              Yes            Yes                  Yes
# 14322  21.0              Yes             No                  NaN
# 14365  18.0              Yes             No                  NaN
# 14396  20.0              Yes             No                  NaN
# 14416  21.0              Yes             No                  NaN
# 14467  21.0              Yes            Yes                  Yes
# 14532  24.0              Yes            NaN                  NaN
# 14562  31.0              Yes            Yes                  Yes
# 14643  20.0              Yes            NaN                  NaN
# 14695  22.0              Yes             No                  NaN
# 14701  23.0              Yes             No                  NaN
# 14751  29.0              Yes            Yes                  Yes
# 14766  25.0              Yes            Yes                   No
# 14987   NaN              Yes             No                  NaN
# 15400  32.0              Yes             No                  NaN
# 15420  25.0              Yes            Yes                  Yes
# 15436  45.0              Yes             No                  NaN
# 15593  29.0              Yes             No                  NaN
#
#       BootcampLoanYesNo                                       BootcampName  \
# 93                   No                                     Codify Academy
# 97                   No                                     DaVinci Coders
# 130                 Yes                                      Coder Foundry
# 159                  No                                   General Assembly
# 188                 Yes                                                NaN
# 206                  No                                           Thinkful
# 209                 Yes                                    Flatiron School
# 236                  No                                   General Assembly
# 272                 Yes                                        DevMountain
# 273                 Yes                                      The Iron Yard
# 285                  No                                             Codeup
# 315                  No                                   General Assembly
# 316                  No                                       Code Fellows
# 328                  No                                            Bloc.io
# 426                 Yes                                   General Assembly
# 435                 Yes                               The Firehose Project
# 449                  No                                   General Assembly
# 465                 Yes                              Prime Digital Academy
# 470                  No                              Prime Digital Academy
# 478                 Yes                              Prime Digital Academy
# 481                  No                              Prime Digital Academy
# 488                 Yes                              Prime Digital Academy
# 505                 Yes  Free Code Camp is not a bootcamp - please scro...
# 510                  No                                    Flatiron School
# 522                 Yes                                          Galvanize
# 525                  No                                                Ada
# 533                  No                                                NaN
# 543                  No                                         Skillcrush
# 549                 NaN                                       Hack Reactor
# 608                  No                                                NaN
# ...                 ...                                                ...
# 14085               NaN                                          CodeaCamp
# 14090               Yes                          Nashville Software School
# 14096               Yes                                        Coder's Lab
# 14102                No                                         Skillcrush
# 14106               Yes                                 Academia de Código
# 14107               Yes                                 Academia de Código
# 14109                No                                CODEcamp Charleston
# 14110                No                                Origin Code Academy
# 14111               NaN                                        TalentBuddy
# 14112               Yes                                          CodeaCamp
# 14114                No                                 Academia de Código
# 14115               Yes                                         10x.org.il
# 14275                No                                      We Got Coders
# 14322                No                                          CodeaCamp
# 14365                No                                  Astro Code School
# 14396                No                                          CodeaCamp
# 14416               Yes                                         10x.org.il
# 14467               Yes                                  Telegraph Academy
# 14532                No                                              Metis
# 14562                No                                      Bitmaker Labs
# 14643                No                                     Codify Academy
# 14695                No                                           AcadGild
# 14701               Yes                                          Devschool
# 14751                No                          Orange County Code School
# 14766                No                                     DaVinci Coders
# 14987                No                                          LAMP Camp
# 15400                No                                      Fire Bootcamp
# 15420                No                                     We Can Code IT
# 15436                No                                     Starter League
# 15593                No                                     Camp Code Away
#
#        BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                    NaN                No            NaN
# 97                45000.0                No            NaN
# 130               75000.0               Yes              3
# 159                   NaN                No            NaN
# 188                   NaN                No            NaN
# 206                   NaN                No              2
# 209                   NaN               Yes            NaN
# 236               45000.0                No            NaN
# 272               50000.0               Yes            NaN
# 273               60000.0               Yes            NaN
# 285               40000.0               Yes            NaN
# 315                   NaN                No            NaN
# 316                   NaN               Yes            NaN
# 328                   NaN               Yes            NaN
# 426                   NaN               Yes            NaN
# 435                   NaN               Yes            NaN
# 449                   NaN               Yes            NaN
# 465                   NaN               Yes            NaN
# 470                   NaN               Yes            NaN
# 478                   NaN               Yes            NaN
# 481                   NaN               Yes            NaN
# 488                   NaN               Yes            NaN
# 505               50000.0               Yes            Yes
# 510                   NaN               Yes            NaN
# 522                   NaN                No            NaN
# 525                   NaN               Yes            NaN
# 533                   NaN               Yes            NaN
# 543               58000.0               Yes            NaN
# 549                   NaN               Yes            NaN
# 608                   NaN                No            NaN
# ...                   ...               ...            ...
# 14085                 NaN               Yes            NaN
# 14090             50000.0               Yes            NaN
# 14096            100000.0               Yes            NaN
# 14102             12000.0               Yes            Yes
# 14106             32400.0               Yes            NaN
# 14107             36000.0               Yes            NaN
# 14109             60000.0               Yes            NaN
# 14110             12000.0               Yes            NaN
# 14111              7992.0               NaN            NaN
# 14112             60000.0               Yes            NaN
# 14114             12000.0               Yes            NaN
# 14115            200000.0                No            NaN
# 14275             31000.0               Yes            NaN
# 14322                 NaN               Yes            NaN
# 14365                 NaN                No            NaN
# 14396                 NaN               Yes            NaN
# 14416                 NaN                No            NaN
# 14467             95000.0               Yes            NaN
# 14532                 NaN               Yes            NaN
# 14562             70000.0               Yes              2
# 14643                 NaN                No            NaN
# 14695                 NaN               Yes            NaN
# 14701                 NaN               Yes            NaN
# 14751             90000.0                No            NaN
# 14766                 NaN                No            NaN
# 14987                 NaN               Yes            NaN
# 15400                 NaN                No            NaN
# 15420             10000.0                No            NaN
# 15436                 NaN               Yes            Yes
# 15593                 NaN                No            NaN
#
#                       CityPopulation  \
# 93     between 100,000 and 1 million
# 97               more than 1 million
# 130                less than 100,000
# 159    between 100,000 and 1 million
# 188    between 100,000 and 1 million
# 206              more than 1 million
# 209              more than 1 million
# 236    between 100,000 and 1 million
# 272    between 100,000 and 1 million
# 273    between 100,000 and 1 million
# 285                              NaN
# 315    between 100,000 and 1 million
# 316    between 100,000 and 1 million
# 328    between 100,000 and 1 million
# 426                less than 100,000
# 435              more than 1 million
# 449              more than 1 million
# 465    between 100,000 and 1 million
# 470    between 100,000 and 1 million
# 478    between 100,000 and 1 million
# 481                less than 100,000
# 488    between 100,000 and 1 million
# 505              more than 1 million
# 510              more than 1 million
# 522                less than 100,000
# 525    between 100,000 and 1 million
# 533    between 100,000 and 1 million
# 543                less than 100,000
# 549    between 100,000 and 1 million
# 608    between 100,000 and 1 million
# ...                              ...
# 14085                            NaN
# 14090            more than 1 million
# 14096                            NaN
# 14102  between 100,000 and 1 million
# 14106                            NaN
# 14107                            NaN
# 14109                            NaN
# 14110                            NaN
# 14111                            NaN
# 14112                            NaN
# 14114  between 100,000 and 1 million
# 14115                            NaN
# 14275              less than 100,000
# 14322  between 100,000 and 1 million
# 14365              less than 100,000
# 14396            more than 1 million
# 14416            more than 1 million
# 14467  between 100,000 and 1 million
# 14532            more than 1 million
# 14562            more than 1 million
# 14643            more than 1 million
# 14695            more than 1 million
# 14701  between 100,000 and 1 million
# 14751  between 100,000 and 1 million
# 14766              less than 100,000
# 14987              less than 100,000
# 15400            more than 1 million
# 15420            more than 1 million
# 15436  between 100,000 and 1 million
# 15593            more than 1 million
#
#                              ...                          \
# 93                           ...
# 97                           ...
# 130                          ...
# 159                          ...
# 188                          ...
# 206                          ...
# 209                          ...
# 236                          ...
# 272                          ...
# 273                          ...
# 285                          ...
# 315                          ...
# 316                          ...
# 328                          ...
# 426                          ...
# 435                          ...
# 449                          ...
# 465                          ...
# 470                          ...
# 478                          ...
# 481                          ...
# 488                          ...
# 505                          ...
# 510                          ...
# 522                          ...
# 525                          ...
# 533                          ...
# 543                          ...
# 549                          ...
# 608                          ...
# ...                          ...
# 14085                        ...
# 14090                        ...
# 14096                        ...
# 14102                        ...
# 14106                        ...
# 14107                        ...
# 14109                        ...
# 14110                        ...
# 14111                        ...
# 14112                        ...
# 14114                        ...
# 14115                        ...
# 14275                        ...
# 14322                        ...
# 14365                        ...
# 14396                        ...
# 14416                        ...
# 14467                        ...
# 14532                        ...
# 14562                        ...
# 14643                        ...
# 14695                        ...
# 14701                        ...
# 14751                        ...
# 14766                        ...
# 14987                        ...
# 15400                        ...
# 15420                        ...
# 15436                        ...
# 15593                        ...
#
#                     CountryLive                        EmploymentField  \
# 93     United States of America  arts, entertainment, sports, or media
# 97     United States of America                   software development
# 130    United States of America                   software development
# 159    United States of America                                    NaN
# 188                      Canada                                    NaN
# 206                       Japan                                    NaN
# 209                      Mexico                                    NaN
# 236    United States of America                   software development
# 272    United States of America                   software development
# 273    United States of America                   software development
# 285    United States of America                   software development
# 315    United States of America                   software development
# 316    United States of America                                    NaN
# 328    United States of America                                  sales
# 426    United States of America                              education
# 435    United States of America                                    NaN
# 449    United States of America                                    NaN
# 465    United States of America                                    NaN
# 470    United States of America                                    NaN
# 478    United States of America                                    NaN
# 481    United States of America                                    NaN
# 488    United States of America                                    NaN
# 505    United States of America            software development and IT
# 510                   Australia                                    NaN
# 522    United States of America                                    NaN
# 525    United States of America                                    NaN
# 533                       India            software development and IT
# 543    United States of America            software development and IT
# 549    United States of America                                    NaN
# 608    United States of America                                    NaN
# ...                         ...                                    ...
# 14085                       NaN                                    NaN
# 14090  United States of America            software development and IT
# 14096                       NaN                                    NaN
# 14102                   Vietnam            software development and IT
# 14106                       NaN                                    NaN
# 14107                       NaN                                    NaN
# 14109                       NaN                                    NaN
# 14110                       NaN                                    NaN
# 14111                       NaN                                    NaN
# 14112                       NaN                                    NaN
# 14114                   Croatia            software development and IT
# 14115                       NaN                                    NaN
# 14275            United Kingdom            software development and IT
# 14322                    Russia            software development and IT
# 14365                   Morocco            software development and IT
# 14396                   Vietnam            software development and IT
# 14416                Bangladesh            software development and IT
# 14467  United States of America            software development and IT
# 14532                    Mexico                              education
# 14562                    Canada            software development and IT
# 14643                     India            software development and IT
# 14695                     India            software development and IT
# 14701                   Romania                                finance
# 14751  United States of America            software development and IT
# 14766  United States of America            software development and IT
# 14987  United States of America      office and administrative support
# 15400              Saudi Arabia            software development and IT
# 15420                     India            software development and IT
# 15436                   Ukraine            construction and extraction
# 15593                     India            software development and IT
#
#                            EmploymentStatus       Gender HasChildren  \
# 93             Self-employed business owner         male         NaN
# 97                       Employed for wages         male          No
# 130                      Employed for wages         male         Yes
# 159    Not working and not looking for work       female         NaN
# 188        Not working but looking for work       female         NaN
# 206      A stay-at-home parent or homemaker       female         Yes
# 209        Not working but looking for work         male         NaN
# 236                Self-employed freelancer         male         NaN
# 272                      Employed for wages         male         NaN
# 273                      Employed for wages         male         NaN
# 285                      Employed for wages         male         NaN
# 315                Self-employed freelancer  genderqueer         NaN
# 316        Not working but looking for work         male         NaN
# 328                      Employed for wages       female         NaN
# 426                      Employed for wages         male         NaN
# 435        Not working but looking for work         male         NaN
# 449        Not working but looking for work       female         NaN
# 465      A stay-at-home parent or homemaker       female         NaN
# 470    Not working and not looking for work       female         NaN
# 478                                     NaN       female         NaN
# 481        Not working but looking for work       female         NaN
# 488                          Unable to work         male         NaN
# 505                      Employed for wages         male         Yes
# 510    Not working and not looking for work         male         NaN
# 522                      Employed for wages         male         NaN
# 525    Not working and not looking for work       female         NaN
# 533                      Employed for wages         male         NaN
# 543                      Employed for wages       female         NaN
# 549                                     NaN       female         NaN
# 608                Self-employed freelancer         male         NaN
# ...                                     ...          ...         ...
# 14085                                   NaN          NaN         NaN
# 14090                    Employed for wages         male          No
# 14096                                   NaN          NaN         NaN
# 14102          Self-employed business owner         male         Yes
# 14106                                   NaN          NaN         NaN
# 14107                                   NaN          NaN         NaN
# 14109                                   NaN          NaN         NaN
# 14110                                   NaN          NaN         NaN
# 14111                                   NaN          NaN         NaN
# 14112                                   NaN          NaN         NaN
# 14114                    Employed for wages         male          No
# 14115                                   NaN          NaN         NaN
# 14275                    Employed for wages         male         NaN
# 14322              Self-employed freelancer         male         NaN
# 14365              Self-employed freelancer         male         NaN
# 14396                    Employed for wages         male          No
# 14416              Self-employed freelancer         male          No
# 14467                    Employed for wages         male         NaN
# 14532                    Employed for wages       female         NaN
# 14562                    Employed for wages       female         Yes
# 14643              Self-employed freelancer         male         NaN
# 14695                    Employed for wages         male          No
# 14701                    Employed for wages         male         NaN
# 14751                    Employed for wages         male          No
# 14766          Self-employed business owner         male         NaN
# 14987                    Employed for wages       female         NaN
# 15400              Self-employed freelancer       female         NaN
# 15420                    Employed for wages         male          No
# 15436              Self-employed freelancer         male         Yes
# 15593                    Employed for wages       female          No
#
#       HoursLearning    Income               JobRoleInterest  \
# 93               20   67000.0                           NaN
# 97               10   40000.0                           NaN
# 130              30   75000.0                           NaN
# 159              30       NaN      Full-Stack Web Developer
# 188              60       NaN                           NaN
# 206              20       NaN              Mobile Developer
# 209              40       NaN      Full-Stack Web Developer
# 236              30   45000.0                           NaN
# 272               5       NaN                           NaN
# 273              10   54000.0                           NaN
# 285              40       NaN                           NaN
# 315              20   35000.0      User Experience Designer
# 316              30       NaN       Front-End Web Developer
# 328              20   35000.0       Front-End Web Developer
# 426              40       NaN      Full-Stack Web Developer
# 435              50       NaN       Front-End Web Developer
# 449              20       NaN                           NaN
# 465               8       NaN    Quality Assurance Engineer
# 470              50       NaN              Mobile Developer
# 478              50       NaN      Full-Stack Web Developer
# 481               2       NaN       Front-End Web Developer
# 488               9       NaN       Front-End Web Developer
# 505              15   38000.0                           NaN
# 510              60       NaN      Full-Stack Web Developer
# 522              10       NaN      Full-Stack Web Developer
# 525              50       NaN      Full-Stack Web Developer
# 533               6    6000.0                           NaN
# 543               5   43000.0                           NaN
# 549              30       NaN      Full-Stack Web Developer
# 608             NaN       NaN                           NaN
# ...             ...       ...                           ...
# 14085            23       NaN                           NaN
# 14090             2   57000.0                           NaN
# 14096            70       NaN                           NaN
# 14102            70   20000.0                           NaN
# 14106           NaN       NaN                           NaN
# 14107            30       NaN                           NaN
# 14109           100       NaN                           NaN
# 14110            10       NaN                           NaN
# 14111           NaN       NaN                           NaN
# 14112             5       NaN                           NaN
# 14114           NaN   12000.0                           NaN
# 14115           NaN       NaN                           NaN
# 14275             3       NaN                           NaN
# 14322            21       NaN                           NaN
# 14365             3       NaN                           NaN
# 14396            20       NaN                           NaN
# 14416            20       NaN                           NaN
# 14467            30       NaN                           NaN
# 14532            20  200000.0                           NaN
# 14562             8   60000.0                           NaN
# 14643           NaN   12000.0                           NaN
# 14695            90   24000.0                           NaN
# 14701             8   60000.0              Mobile Developer
# 14751            20   48000.0                           NaN
# 14766            50   48000.0      Full-Stack Web Developer
# 14987            40   60000.0                           NaN
# 15400            12   24000.0                           NaN
# 15420           NaN   12000.0                           NaN
# 15436             5   36000.0      Full-Stack Web Developer
# 15593             5  200000.0                           NaN
#
#                                    SchoolDegree  \
# 93                            bachelor's degree
# 97           master's degree (non-professional)
# 130              some college credit, no degree
# 159              some college credit, no degree
# 188              some college credit, no degree
# 206                           bachelor's degree
# 209     professional degree (MBA, MD, JD, etc.)
# 236              some college credit, no degree
# 272                           bachelor's degree
# 273                           bachelor's degree
# 285                           bachelor's degree
# 315                           bachelor's degree
# 316                          associate's degree
# 328                           bachelor's degree
# 426                           bachelor's degree
# 435                          associate's degree
# 449                           bachelor's degree
# 465          master's degree (non-professional)
# 470                           bachelor's degree
# 478                           bachelor's degree
# 481    trade, technical, or vocational training
# 488                           bachelor's degree
# 505              some college credit, no degree
# 510    trade, technical, or vocational training
# 522                           bachelor's degree
# 525                           bachelor's degree
# 533                           bachelor's degree
# 543                           bachelor's degree
# 549                           bachelor's degree
# 608                           bachelor's degree
# ...                                         ...
# 14085                                       NaN
# 14090  trade, technical, or vocational training
# 14096                                       NaN
# 14102   professional degree (MBA, MD, JD, etc.)
# 14106                                       NaN
# 14107                                       NaN
# 14109                                       NaN
# 14110                                       NaN
# 14111                                       NaN
# 14112                                       NaN
# 14114                         bachelor's degree
# 14115                                       NaN
# 14275                         bachelor's degree
# 14322   high school diploma or equivalent (GED)
# 14365                          some high school
# 14396                          some high school
# 14416                                     Ph.D.
# 14467                        associate's degree
# 14532                         bachelor's degree
# 14562                         bachelor's degree
# 14643         no high school (secondary school)
# 14695                         bachelor's degree
# 14701                          some high school
# 14751                         bachelor's degree
# 14766  trade, technical, or vocational training
# 14987                        associate's degree
# 15400   professional degree (MBA, MD, JD, etc.)
# 15420                         bachelor's degree
# 15436   high school diploma or equivalent (GED)
# 15593                         bachelor's degree
#
#                                              SchoolMajor
# 93                                               Biology
# 97                                                 Music
# 130                                                  NaN
# 159                                                  NaN
# 188                                                  NaN
# 206                                       Communications
# 209                                     Computer Science
# 236                                                  NaN
# 272                               Structural Engineering
# 273                                Public Administration
# 285                                           Journalism
# 315                                       Communications
# 316                                      General Studies
# 328                            Advertising and Marketing
# 426                                         Liberal Arts
# 435                                           Psychology
# 449                                         Architecture
# 465                                              English
# 470                                         Liberal Arts
# 478                                            Sociology
# 481                                                  NaN
# 488                                           Psychology
# 505                                                  NaN
# 510                                                  NaN
# 522                                           Psychology
# 525                                           Psychology
# 533                                       Communications
# 543                              Business Administration
# 549                                Environmental Science
# 608                                                Music
# ...                                                  ...
# 14085                                                NaN
# 14090                                                NaN
# 14096                                                NaN
# 14102                                               Math
# 14106                                                NaN
# 14107                                                NaN
# 14109                                                NaN
# 14110                                                NaN
# 14111                                                NaN
# 14112                                                NaN
# 14114                                   Computer Science
# 14115                                                NaN
# 14275                                          Economics
# 14322                                                NaN
# 14365                                                NaN
# 14396                                                NaN
# 14416                                   Computer Science
# 14467                                          Sociology
# 14532                       Technology Teacher Education
# 14562                                     Graphic Design
# 14643                                                NaN
# 14695                                   Computer Science
# 14701                                                NaN
# 14751                             Industrial Engineering
# 14766                                                NaN
# 14987                                Computer Networking
# 15400  Computer Systems Networking and Telecommunicat...
# 15420                             Information Technology
# 15436                                                NaN
# 15593                                         Accounting
#
# [389 rows x 21 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp

# %%
# Merge the two created data frames on the name of tbe bootcamp

# %%
# Calculate percentage of eac bootcamp's students who are recommenders

# %%
# Export to excel and remove index
