# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
csvpath = os.path.join('Resources', 'avg_rain_state.csv')
rain_df = pd.read_csv(csvpath)
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x values
x_values = np.arange(len(rain_df))

# %%
# Set figure size to adjust for space
plt.figure(figsize=(20, 5))
# Create a bar chart
plt.bar(x_values, rain_df["Inches"], color='r', alpha=0.5)
# Create ticks
plt.xticks(x_values, rain_df["State"], rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x115e3ac18>,
#   <matplotlib.axis.XTick at 0x11e2f2f98>,
#   <matplotlib.axis.XTick at 0x115e56278>,
#   <matplotlib.axis.XTick at 0x11e41bb70>,
#   <matplotlib.axis.XTick at 0x11e42a588>,
#   <matplotlib.axis.XTick at 0x11e42af60>,
#   <matplotlib.axis.XTick at 0x11e431978>,
#   <matplotlib.axis.XTick at 0x11e437390>,
#   <matplotlib.axis.XTick at 0x11e437d68>,
#   <matplotlib.axis.XTick at 0x11e43c780>,
#   <matplotlib.axis.XTick at 0x11e445198>,
#   <matplotlib.axis.XTick at 0x11e445b70>,
#   <matplotlib.axis.XTick at 0x11e44c588>,
#   <matplotlib.axis.XTick at 0x11e44cf60>,
#   <matplotlib.axis.XTick at 0x11e452978>,
#   <matplotlib.axis.XTick at 0x11e458390>,
#   <matplotlib.axis.XTick at 0x11e458d68>,
#   <matplotlib.axis.XTick at 0x11e45e780>,
#   <matplotlib.axis.XTick at 0x11e466198>,
#   <matplotlib.axis.XTick at 0x11e466b70>,
#   <matplotlib.axis.XTick at 0x11e46c588>,
#   <matplotlib.axis.XTick at 0x11e46cf60>,
#   <matplotlib.axis.XTick at 0x11e473978>,
#   <matplotlib.axis.XTick at 0x11e479390>,
#   <matplotlib.axis.XTick at 0x11e479d68>,
#   <matplotlib.axis.XTick at 0x11e47f780>,
#   <matplotlib.axis.XTick at 0x11e485198>,
#   <matplotlib.axis.XTick at 0x11e485b70>,
#   <matplotlib.axis.XTick at 0x11e48c588>,
#   <matplotlib.axis.XTick at 0x11e48cf60>,
#   <matplotlib.axis.XTick at 0x11e493978>,
#   <matplotlib.axis.XTick at 0x11e49a390>,
#   <matplotlib.axis.XTick at 0x11e49ad68>,
#   <matplotlib.axis.XTick at 0x11e4a1780>,
#   <matplotlib.axis.XTick at 0x11e4a9198>,
#   <matplotlib.axis.XTick at 0x11e4a9b70>,
#   <matplotlib.axis.XTick at 0x11e4af588>,
#   <matplotlib.axis.XTick at 0x11e4aff60>,
#   <matplotlib.axis.XTick at 0x11e4b5978>,
#   <matplotlib.axis.XTick at 0x11e4bb390>,
#   <matplotlib.axis.XTick at 0x11e4bbd68>,
#   <matplotlib.axis.XTick at 0x11e4c3780>,
#   <matplotlib.axis.XTick at 0x11e4ca198>,
#   <matplotlib.axis.XTick at 0x11e4cab70>,
#   <matplotlib.axis.XTick at 0x11e4d1588>,
#   <matplotlib.axis.XTick at 0x11e4d1f60>,
#   <matplotlib.axis.XTick at 0x11e4d7978>,
#   <matplotlib.axis.XTick at 0x11e4dd390>,
#   <matplotlib.axis.XTick at 0x11e4ddd68>,
#   <matplotlib.axis.XTick at 0x11e4e5780>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-1, len(x_values))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.700000000000003)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart
# of the data
state_and_inches.plot(kind="bar", figsize=(20, 5))

# Pandas uses matplotlib, so you can still edit the chart
# in the same way you would edit a matplotlib bar chart.

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()

# %%
# Pandas can also plot multiple columns if the DataFrame
# includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20, 5))
print(type(multi_plot))

# PandasPlot.set_xticklabels() can be used
# to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
