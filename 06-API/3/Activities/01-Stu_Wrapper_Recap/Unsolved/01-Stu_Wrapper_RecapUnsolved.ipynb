# %%
# Dependencies
import openweathermapy.core as owm
import json
import requests as req
from pprint import pprint

# %%
# Create settings parameters
url = 'http://api.openweathermap.org/data/2.5/forecast'
api_key = '23c333dd9ad6b00441baded0602a84c7'
city = 'Phoenix'
parameters = {'appid':api_key, 'q': city}

# %%
# make the API call using a method from openweathermapy that 
# returns hourly forecasts for Phoenix, AZ and prints the result
forecast_json = req.get(url, params = parameters ).json()
pprint(forecast_json)
# Out:
# {'city': {'coord': {'lat': 33.4486, 'lon': -112.0774},
#           'country': 'US',
#           'id': 5308655,
#           'name': 'Phoenix',
#           'population': 1445632},
#  'cnt': 39,
#  'cod': '200',
#  'list': [{'clouds': {'all': 12},
#            'dt': 1521082800,
#            'dt_txt': '2018-03-15 03:00:00',
#            'main': {'grnd_level': 969.68,
#                     'humidity': 52,
#                     'pressure': 969.68,
#                     'sea_level': 1022.28,
#                     'temp': 295.02,
#                     'temp_kf': 1.38,
#                     'temp_max': 295.02,
#                     'temp_min': 293.649},
#            'rain': {'3h': 0.18},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 231.508, 'speed': 4.38}},
#           {'clouds': {'all': 64},
# ...

# %%
# use a method from openweatherpy and list comprehension  
# to extract the date in text and the temperature and store in a list

# %%
# print formatted results

# %%
# BONUS 1
# Use a method from openweathermapy that will extract the desired data
# without requiring a loop, and then print formatted results

# %%
# BONUS 2 : Plot the forecasted temperature over time.
