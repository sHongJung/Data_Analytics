# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
gkey = "AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw"

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("cities.csv")
cities_pd.head()
# Out:
#            City         State
# 0      New York      New York
# 1   Los Angeles    California
# 2       Chicago      Illinois
# 3       Houston         Texas
# 4  Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#            City         State Lat Lng Airport Name Airport Address  \
# 0      New York      New York
# 1   Los Angeles    California
# 2       Chicago      Illinois
# 3       Houston         Texas
# 4  Philadelphia  Pennsylvania
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    target_url = "https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (row["City"], gkey)
    cities_lat_lng = requests.get(target_url).json()
    cities_pd.set_value(index, "Lat", cities_lat_lng["results"][0]["geometry"]["location"]["lat"])
    cities_pd.set_value(index, "Lng", cities_lat_lng["results"][0]["geometry"]["location"]["lng"])
    print(target_url)
                
# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=New York&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Los Angeles&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chicago&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Houston&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Philadelphia&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Phoenix&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San Antonio&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San Diego&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Dallas&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San Jose&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Austin&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Jacksonville&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San Francisco&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Indianapolis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Columbus&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fort Worth&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Seattle&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Denver&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=El Paso&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Detroit&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Washington&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Boston&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Memphis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Nashville&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Portland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Oklahoma City&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Las Vegas&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Baltimore&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Louisville&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Milwaukee&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Albuquerque&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Tucson&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fresno&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Sacramento&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Kansas City&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Long Beach&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Mesa&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Atlanta&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Colorado Springs&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Virginia Beach&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Raleigh&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Omaha&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Miami&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Oakland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Minneapolis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Tulsa&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Wichita&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=New Orleans&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Arlington&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Cleveland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Bakersfield&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Tampa&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Aurora&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Honolulu&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Anaheim&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Santa Ana&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Corpus Christi&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Riverside&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=St. Louis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Lexington&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Stockton&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Pittsburgh&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Saint Paul&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Anchorage&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Cincinnati&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Henderson&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Greensboro&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Plano&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Newark&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Toledo&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Lincoln&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Orlando&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chula Vista&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Jersey City&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chandler&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fort Wayne&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Durham&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=St. Petersburg&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Irvine&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Laredo&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Lubbock&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Madison&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Gilbert&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Norfolk&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Reno&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Winston-Salem&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Glendale&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Hialeah&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Garland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Scottsdale&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Irving&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chesapeake&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=North Las Vegas&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fremont&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Baton Rouge&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Richmond&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Boise&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San Bernardino&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
#            City         State      Lat      Lng Airport Name Airport Address  \
# 0      New York      New York  40.7128 -74.0059
# 1   Los Angeles    California  34.0522 -118.244
# 2       Chicago      Illinois  41.8781 -87.6298
# 3       Houston         Texas  29.7604 -95.3698
# 4  Philadelphia  Pennsylvania  39.9526 -75.1652
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4
