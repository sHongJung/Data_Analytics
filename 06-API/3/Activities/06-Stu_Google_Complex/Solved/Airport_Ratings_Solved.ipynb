# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
gkey = "AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw"

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("cities.csv")
cities_pd.head()
# Out:
#            City         State
# 0      New York      New York
# 1   Los Angeles    California
# 2       Chicago      Illinois
# 3       Houston         Texas
# 4  Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#            City         State Lat Lng Airport Name Airport Address  \
# 0      New York      New York
# 1   Los Angeles    California
# 2       Chicago      Illinois
# 3       Houston         Texas
# 4  Philadelphia  Pennsylvania
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    target_url = "https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (row["City"].replace(" ","+"), gkey)
    cities_lat_lng = requests.get(target_url).json()
    cities_pd.set_value(index, "Lat", cities_lat_lng["results"][0]["geometry"]["location"]["lat"])
    cities_pd.set_value(index, "Lng", cities_lat_lng["results"][0]["geometry"]["location"]["lng"])
    print(target_url)
                
# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Los+Angeles&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chicago&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Houston&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Philadelphia&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Phoenix&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San+Antonio&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San+Diego&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Dallas&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San+Jose&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Austin&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Jacksonville&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San+Francisco&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Indianapolis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Columbus&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fort+Worth&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Seattle&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Denver&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=El+Paso&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Detroit&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Washington&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Boston&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Memphis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Nashville&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Portland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Oklahoma+City&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Las+Vegas&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Baltimore&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Louisville&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Milwaukee&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Albuquerque&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Tucson&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fresno&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Sacramento&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Kansas+City&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Long+Beach&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Mesa&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Atlanta&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Colorado+Springs&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Virginia+Beach&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Raleigh&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Omaha&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Miami&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Oakland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Minneapolis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Tulsa&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Wichita&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=New+Orleans&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Arlington&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Cleveland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Bakersfield&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Tampa&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Aurora&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Honolulu&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Anaheim&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Santa+Ana&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Corpus+Christi&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Riverside&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=St.+Louis&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Lexington&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Stockton&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Pittsburgh&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Saint+Paul&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Anchorage&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Cincinnati&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Henderson&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Greensboro&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Plano&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Newark&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Toledo&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Lincoln&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Orlando&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chula+Vista&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Jersey+City&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chandler&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fort+Wayne&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Durham&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=St.+Petersburg&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Irvine&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Laredo&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Lubbock&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Madison&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Gilbert&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Norfolk&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Reno&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Winston-Salem&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Glendale&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Hialeah&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Garland&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Scottsdale&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Irving&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Chesapeake&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=North+Las+Vegas&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Fremont&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Baton+Rouge&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Richmond&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=Boise&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/geocode/json?address=San+Bernardino&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
#            City         State      Lat      Lng Airport Name Airport Address  \
# 0      New York      New York  40.7128  -74.006
# 1   Los Angeles    California  34.0522 -118.244
# 2       Chicago      Illinois  41.8781 -87.6298
# 3       Houston         Texas  29.7604 -95.3698
# 4  Philadelphia  Pennsylvania  39.9526 -75.1652
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# Use the lat/lng we recovered to identify airports
for index, row in cities_pd.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Use the search term: "International Airport" and our lat/lng
    target_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=%s,%s&radius=50000&types=%s&keyword=international+airport&key=%s" % (lat, lng, "airport", gkey)
    name_address = requests.get(target_url).json()
    print(target_url)
    # print(json.dumps(name_address, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_pd.set_value(index, "Airport Name", name_address["results"][0]["name"])
        cities_pd.set_value(index, "Airport Address", name_address["results"][0]["vicinity"])
        cities_pd.set_value(index, "Airport Rating", name_address["results"][0]["rating"])
    
    except:
        print("Missing field... skipping.")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7127753,-74.0059728&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.0522342,-118.2436849&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.8781136,-87.6297982&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=29.7604267,-95.3698028&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.9525839,-75.1652215&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.4483771,-112.0740373&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=29.4241219,-98.49362819999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.715738,-117.1610838&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.7766642,-96.79698789999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.3382082,-121.8863286&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.267153,-97.7430608&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.3321838,-81.65565099999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.7749295,-122.4194155&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.768403,-86.158068&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.9611755,-82.99879419999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.7554883,-97.3307658&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.2270869,-80.8431267&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47.6062095,-122.3320708&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.7392358,-104.990251&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=31.7618778,-106.4850217&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.331427,-83.0457538&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47.7510741,-120.7401385&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.3600825,-71.0588801&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.1495343,-90.0489801&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.1626638,-86.7816016&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=45.5230622,-122.6764815&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.4675602,-97.5164276&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.1699412,-115.1398296&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.2903848,-76.6121893&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.2526647,-85.7584557&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.0389025,-87.9064736&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.0853336,-106.6055534&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.2217429,-110.926479&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.7468422,-119.7725868&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.5815719,-121.4943996&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.0997265,-94.5785667&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.7700504,-118.1937395&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.4151843,-111.8314724&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.7489954,-84.3879824&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.8338816,-104.8213634&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.8529263,-75.97798499999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.7795897,-78.6381787&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.2523634,-95.99798829999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=25.7616798,-80.1917902&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.8043637,-122.2711137&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.977753,-93.2650108&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.1539816,-95.99277500000001&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.68717609999999,-97.33005299999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=29.95106579999999,-90.0715323&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.8816208,-77.09098089999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.49932,-81.6943605&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.3732921,-119.0187125&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=27.950575,-82.4571776&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.7294319,-104.8319195&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=21.3069444,-157.8583333&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.8365932,-117.9143012&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.7454725,-117.867653&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=27.8005828,-97.39638099999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.9533487,-117.3961564&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.6270025,-90.19940419999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.0405837,-84.5037164&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Missing field... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.4941665,-74.53237949999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.44062479999999,-79.9958864&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.9537029,-93.0899578&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=61.2180556,-149.9002778&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.1031182,-84.5120196&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.0395247,-114.9817213&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.0726354,-79.7919754&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.0198431,-96.6988856&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.6895314,-74.1744624&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.6639383,-83.55521200000001&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.8257625,-96.6851982&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=28.5383355,-81.3792365&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.6400541,-117.0841955&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.72815749999999,-74.0776417&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.3061605,-111.8412502&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.079273,-85.1393513&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.88644679999999,-78.8783689&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.9940329,-78.898619&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=59.9342802,30.3350986&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.6845673,-117.8265049&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=27.5305671,-99.48032409999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.5778631,-101.8551665&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.0730517,-89.4012302&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.3528264,-111.789027&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.8507689,-76.28587259999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.5296329,-119.8138027&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.09985959999999,-80.244216&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.1425078,-118.255075&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=25.8575963,-80.2781057&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.912624,-96.63888329999999&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.4941704,-111.9260519&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.8140177,-96.9488945&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.7682088,-76.2874927&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.1988592,-115.1175013&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.5482697,-121.9885719&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4582829,-91.1403196&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.5407246,-77.4360481&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.6187102,-116.2146068&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Missing field... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.1083449,-117.2897652&radius=50000&types=airport&keyword=international+airport&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw

# %%
# Save Data to csv
cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
cities_pd.head(10)
# Out:
#            City         State      Lat      Lng  \
# 0      New York      New York  40.7128  -74.006
# 1   Los Angeles    California  34.0522 -118.244
# 2       Chicago      Illinois  41.8781 -87.6298
# 3       Houston         Texas  29.7604 -95.3698
# 4  Philadelphia  Pennsylvania  39.9526 -75.1652
# 5       Phoenix       Arizona  33.4484 -112.074
# 6   San Antonio         Texas  29.4241 -98.4936
# 7     San Diego    California  32.7157 -117.161
# 8        Dallas         Texas  32.7767  -96.797
# 9      San Jose    California  37.3382 -121.886
#
#                                Airport Name  \
# 0      Newark Liberty International Airport
# 1         Los Angeles International Airport
# 2  Bolingbrook's Clow International Airport
# 3                  William P. Hobby Airport
# 4        Philadelphia International Airport
# 5  Phoenix Sky Harbor International Airport
# 6         San Antonio International Airport
# 7           San Diego International Airport
# 8   Dallas/Fort Worth International Airport
# 9             Oakland International Airport
#
#                                  Airport Address Airport Rating
# 0                        3 Brewster Road, Newark            3.3
# 1                       1 World Way, Los Angeles            3.5
# 2  130 Clow International Parkway C, Bolingbrook            4.3
# 3                7800 Airport Boulevard, Houston            4.1
# 4               8000 Essington Ave, Philadelphia            3.3
# 5        3400 East Sky Harbor Boulevard, Phoenix            3.9
# 6            9800 Airport Boulevard, San Antonio            3.9
# 7             3225 North Harbor Drive, San Diego            3.9
# 8         2400 Aviation Drive North, DFW Airport            3.8
# 9                       1 Airport Drive, Oakland            3.9
