# %%
# Dependencies
import tweepy
import json

# Twitter API Keys
consumer_key = "YOUR_KEY"
consumer_secret = "YOUR_KEY"
access_token = "YOUR_KEY"
access_token_secret = "YOUR KEY"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# "Real Person" Filters
min_tweets = 5
max_tweets = 100000
min_followers = 9
max_following = 2500
lang = "en"

# Search for People Tweeting about Katy Perry
search_term = "Katy Perry"

# Array of Eligible Tweets
tweet_array = []

# Retrieve 100 tweets
public_tweets = api.search(search_term, count=100)

#Create a filter using a custom function
def is_good_tweet(tweet):
    if (tweet["user"]["followers_count"] < max_followers and
        tweet["user"]["statuses_count"] > min_tweets and
        tweet["user"]["statuses_count"] < max_tweets and
        tweet["user"]["friends_count"] < max_following and
            tweet["user"]["lang"] == lang):
        return True
    else:
        return False

# Proceed to printing only filtered tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(
    #     tweet, sort_keys=True, indent=4, separators=(',', ': ')))

    # Use filters to check if user meets conditions
    
    if is_good_tweet(tweet):
        # If so add the user's tweet to the array (for future use)
        tweet_array.append(tweet["text"])

        # Print the username
        print(tweet["user"]["screen_name"])

        # Print the tweet text
        print(tweet["text"].encode("UTF-8"))
        print("")

# Print total number of tweets
print(len(tweet_array))
# Out:
# KenSemBarbie
# b'RT @RafaeIVentura: KATY PERRY PISTOLANDO PQ ATRASARAM O MEET QUE ELA FAZ DE GRA\xc3\x87A NO RIO QUERENDO PASSAR O RESTANTE PRA DEPOIS DO SHOW PQ N\xe2\x80\xa6'
#
# TDawg_goinHAM
# b'RT @jennamccauleyyy: I freaking love Katy Perry \xf0\x9f\x98\xa9\xf0\x9f\x98\xa9'
#
# sportell_
# b"Katy Perry is annoying and I feel like she joined idol to scrape what's left of her career after being called out f\xe2\x80\xa6 https://t.co/8sujjcCmfR"
#
# R_of_R
# b'@Thomas1774Paine Katy Perry is a greed driven Satanic cunt. Perfect fit for Hollywood.'
#
# TatahLopes
# b'Evan Rachel Wood, Kristin Bauer, Viola Davis, Katy Perry... um monte de gringo tendo um posicionamento decente e os\xe2\x80\xa6 https://t.co/bUclOvOFz4'
#
# MY_1025
# b'Katy Perry Reveals Her Hit Single That She Has Trouble Singing https://t.co/8WCiimnxlY'
#
# dontmakeme_wing
# b'Never thought I\xe2\x80\x99d say this, but I am HERE for Katy Perry as an American idol judge.'
#
# moteleyes69
# b"News &amp; views: Katy Perry is dragging down 'American Idol' https://t.co/VH9kCqZdFZ?"
#
# jadecruzan
# b'It\xe2\x80\x99s your Taylor Swift year, but I know deep down you love Katy Perry more. Thanks for always being down for sushi\xe2\x80\xa6 https://t.co/uCm6960ZL1'
#
# atheahafidz
# b"RT @nowthisnews: Katy Perry kissed an 'American Idol' contestant \xe2\x80\x94 and he really didn't like it https://t.co/VqEukzHZL2"
#
# hstyls96
# b"RT @repts1989: Sorry media but,even if i am not a Katy Perry fan, i can tell, that she was so respectful to Taylor.She didn't say something\xe2\x80\xa6"
#
# Lucasjrdeblock
# b'RT @Manny_1027: Update: I bodied dirty little secret. Like literally bodied. It was so bad. Oh well. Lucas and I are about to do a duet to\xe2\x80\xa6'
#
# ErnestoDeplora2
# b'@Gruvedawg @Thomas1774Paine "At the same time, Manson\'s followers butchered couple Leno and Rosemary LaBianca in th\xe2\x80\xa6 https://t.co/XPbVcK0XOX'
#
# StarHitMusic
# b'Katy Perry Reveals Her Hit Single That She Has Trouble Singinghttp://ihe.art/MyVQ3Ym'
#
# ShaayxMitch
# b'@Katy_Perry_O2 @Imrraven Baia, baia. https://t.co/kE2tOOzDSD'
#
# Y100Florida
# b'Katy Perry Reveals Her Hit Single That She Has Trouble Singing https://t.co/9dPEgxM9Zt'
#
# tswizzle_161
# b'RT @_GuySwiftie13: As much as there is Katy vs Taylor drama... Katy Perry DID NOT diss Taylor on American Idol. Her response was casual and\xe2\x80\xa6'
#
# q105radio
# b'Katy Perry Reveals Her Hit Single That She Has Trouble Singing https://t.co/CIKi4g4Bq0'
#
# 983TRY
# b'Katy Perry Reveals Her Hit Single That She Has Trouble Singing https://t.co/CAVZ2RrMIf'
#
# totallymatthewg
# b'RT @FroPaz444: Katy Perry tricking that boy into kissing her was disgusting, and the reaction to it being, "He must be gay for not wanting\xe2\x80\xa6'
#
# ShaayxMitch
# b'@Katy_Perry_O2 @Imrraven Hola chiquita. https://t.co/ipUXEyF8R7'
#
# 21
