# %%
import tweepy
from pprint import pprint
import twitter_api as ta
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Twitter API Keys
consumer_key = ta.consumer_key
consumer_secret = ta.consumer_secret
access_token = ta.access_token
access_token_secret = ta.access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

analyzer = SentimentIntensityAnalyzer()

# %%
target_user = "DalaiLama"
tweet_text = []
public_tweets = api.user_timeline(target_user)
pprint(public_tweets)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 19 10:04:17 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/975674309736828928',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/1GLcRq1O13'}],
#                'user_mentions': []},
#   'favorite_count': 50061,
#   'favorited': False,
#   'geo': None,
#   'id': 975674309736828928,
#   'id_str': '975674309736828928',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 17717,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'The many factors which divide us are actually much more superficial '
#           'than those we share. Despite all of the things… '
#           'https://t.co/1GLcRq1O13',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Mar 16 09:54:32 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/974584694644854784',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/2N48cruRKM'}],
#                'user_mentions': []},
#   'favorite_count': 75076,
#   'favorited': False,
#   'geo': None,
#   'id': 974584694644854784,
#   'id_str': '974584694644854784',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 26991,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'When each of us learns to appreciate the critical importance of '
#           'ethics and makes inner values like compassion and p… '
#           'https://t.co/2N48cruRKM',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 12 10:30:23 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/973144164408885248',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/uz9vqPlULu'}],
#                'user_mentions': []},
#   'favorite_count': 118224,
#   'favorited': False,
#   'geo': None,
#   'id': 973144164408885248,
#   'id_str': '973144164408885248',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 46301,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'In today’s materialistic world there is a risk of people becoming '
#           'slaves to money, as though they were simply cogs… '
#           'https://t.co/uz9vqPlULu',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Mar 09 10:33:52 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/972057875941076992',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/E424tZwYCU'}],
#                'user_mentions': []},
#   'favorite_count': 8591,
#   'favorited': False,
#   'geo': None,
#   'id': 972057875941076992,
#   'id_str': '972057875941076992',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2488,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Watch "Compassion and the Role of Women" - HHDL\'s remarks to a '
#           'group of women about their role in promoting human v… '
#           'https://t.co/E424tZwYCU',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 07 10:30:05 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/971332151240155136',
#                          'indices': [121, 144],
#                          'url': 'https://t.co/hc6JyKfFRB'}],
#                'user_mentions': []},
#   'favorite_count': 5454,
#   'favorited': False,
#   'geo': None,
#   'id': 971332151240155136,
#   'id_str': '971332151240155136',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1513,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Watch Live: Mind &amp; Life Dialogue “Reimagining Human '
#           'Flourishing” from Dharamsala, India on March 12-16. HHDL will e… '
#           'https://t.co/hc6JyKfFRB',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 06 10:30:11 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/970969787856637953',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/LSrBjonqut'}],
#                'user_mentions': []},
#   'favorite_count': 78787,
#   'favorited': False,
#   'geo': None,
#   'id': 970969787856637953,
#   'id_str': '970969787856637953',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 30547,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Peace has a great deal to do with warm-heartedness and respect for '
#           'the lives of others, avoiding doing them harm an… '
#           'https://t.co/LSrBjonqut',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Mar 02 10:30:16 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/969520256095064064',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/iNGWETo3Qv'}],
#                'user_mentions': []},
#   'favorite_count': 57811,
#   'favorited': False,
#   'geo': None,
#   'id': 969520256095064064,
#   'id_str': '969520256095064064',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 19745,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Insofar as the destructive effects of anger and hateful thoughts '
#           'are concerned, one cannot get protection from weal… '
#           'https://t.co/iNGWETo3Qv',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 26 10:30:15 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/968070699708379143',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/tjM74upGNj'}],
#                'user_mentions': []},
#   'favorite_count': 111420,
#   'favorited': False,
#   'geo': None,
#   'id': 968070699708379143,
#   'id_str': '968070699708379143',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 38150,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Because of the great differences in our ways of thinking, it is '
#           'inevitable that we have different religions and fai… '
#           'https://t.co/tjM74upGNj',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Feb 23 10:30:07 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/966983501336711168',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/uxCctovIlU'}],
#                'user_mentions': []},
#   'favorite_count': 78859,
#   'favorited': False,
#   'geo': None,
#   'id': 966983501336711168,
#   'id_str': '966983501336711168',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 30619,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Practicing compassion, caring for others and sharing their '
#           'problems, lays the foundation for a meaningful life, not… '
#           'https://t.co/uxCctovIlU',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 19 10:30:08 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/965533955045974016',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/ivBKZxq8QN'}],
#                'user_mentions': []},
#   'favorite_count': 121166,
#   'favorited': False,
#   'geo': None,
#   'id': 965533955045974016,
#   'id_str': '965533955045974016',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 48874,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'The very purpose of spirituality is self-discipline. Rather than '
#           'criticizing others, we should evaluate and critici… '
#           'https://t.co/ivBKZxq8QN',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Feb 16 10:30:01 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/964446764739760128',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/IP1mpblTTQ'}],
#                'user_mentions': []},
#   'favorite_count': 153127,
#   'favorited': False,
#   'geo': None,
#   'id': 964446764739760128,
#   'id_str': '964446764739760128',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 58400,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Genuine friends, are attracted by a warm heart, not money, not '
#           'power. A genuine friend considers you as just anothe… '
#           'https://t.co/IP1mpblTTQ',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 12 10:30:10 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/962997250187128833',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/ySHNbQYUwq'}],
#                'user_mentions': []},
#   'favorite_count': 67724,
#   'favorited': False,
#   'geo': None,
#   'id': 962997250187128833,
#   'id_str': '962997250187128833',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 24765,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Compassion suits our physical condition, whereas anger, fear and '
#           'distrust are harmful to our well-being. Therefore,… '
#           'https://t.co/ySHNbQYUwq',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Feb 09 10:31:23 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/961910390874562560',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/xCakNIjXUW'}],
#                'user_mentions': []},
#   'favorite_count': 229154,
#   'favorited': False,
#   'geo': None,
#   'id': 961910390874562560,
#   'id_str': '961910390874562560',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 74188,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Although I am a Buddhist monk, I am skeptical that prayers alone '
#           'will achieve world peace. We need instead to be en… '
#           'https://t.co/xCakNIjXUW',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 05 10:30:20 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/960460574948712448',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/OmPoNeglAp'}],
#                'user_mentions': []},
#   'favorite_count': 62554,
#   'favorited': False,
#   'geo': None,
#   'id': 960460574948712448,
#   'id_str': '960460574948712448',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 23095,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'I believe the ultimate source of blessings is within us. A good '
#           'motivation and honesty bring self-confidence, which… '
#           'https://t.co/OmPoNeglAp',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
# ...
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 26 10:30:05 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/956836633600409601',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/ffCFC6YxcV'}],
#                'user_mentions': []},
#   'favorite_count': 69172,
#   'favorited': False,
#   'geo': None,
#   'id': 956836633600409601,
#   'id_str': '956836633600409601',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 26333,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Developing inner values is much like physical exercise. The more we '
#           'train our abilities, the stronger they become.… '
#           'https://t.co/ffCFC6YxcV',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jan 22 10:30:25 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/955387165919166464',
#                          'indices': [117, 140],
#                          'url': 'https://t.co/Gxr1vBfD7v'}],
#                'user_mentions': []},
#   'favorite_count': 111839,
#   'favorited': False,
#   'geo': None,
#   'id': 955387165919166464,
#   'id_str': '955387165919166464',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 51639,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'What’s past is past, nothing can change that. But the future can be '
#           'different if we choose to make it so. We have t… '
#           'https://t.co/Gxr1vBfD7v',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 19 10:30:17 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/954299970244378625',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/pkGXYbHUKz'}],
#                'user_mentions': []},
#   'favorite_count': 71267,
#   'favorited': False,
#   'geo': None,
#   'id': 954299970244378625,
#   'id_str': '954299970244378625',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 27524,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Destructive thoughts and emotions undermine the very causes of '
#           'peace and happiness. If you think clearly about it,… '
#           'https://t.co/pkGXYbHUKz',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jan 15 10:30:50 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                          'expanded_url': 'https://twitter.com/i/web/status/952850556330033152',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/XUTgOYBd9l'}],
#                'user_mentions': []},
#   'favorite_count': 79460,
#   'favorited': False,
#   'geo': None,
#   'id': 952850556330033152,
#   'id_str': '952850556330033152',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 27132,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Modern education pays little attention to inner values and yet our '
#           'basic human nature is compassionate. We need to… '
#           'https://t.co/XUTgOYBd9l',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Wed Feb 11 18:34:22 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Welcome to the official twitter page of the Office '
#                           'of His Holiness the 14th Dalai Lama.',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'dalailama.com',
#                                           'expanded_url': 'http://dalailama.com',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/AKctyfx8On'}]}},
#            'favourites_count': 0,
#            'follow_request_sent': False,
#            'followers_count': 18137382,
#            'following': False,
#            'friends_count': 0,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 20609518,
#            'id_str': '20609518',
#            'is_translation_enabled': True,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 81960,
#            'location': 'Dharamsala, India',
#            'name': 'Dalai Lama',
#            'notifications': False,
#            'profile_background_color': 'FFD21D',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/78185270/hhdl-twitter-bg.jpg',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529214699041067008/fqPBAr5s_normal.jpeg',
#            'profile_link_color': '7D1900',
#            'profile_sidebar_border_color': 'E8E3CE',
#            'profile_sidebar_fill_color': 'F7F2DC',
#            'profile_text_color': '000000',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'DalaiLama',
#            'statuses_count': 1335,
#            'time_zone': 'New Delhi',
#            'translator_type': 'none',
#            'url': 'http://t.co/AKctyfx8On',
#            'utc_offset': 19800,
#            'verified': True}}]

# %%
for tweet in public_tweets:
    tweet_text.append(tweet['text'])
    
print(tweet_text)
# Out:
# ['The many factors which divide us are actually much more superficial than those we share. Despite all of the things… https://t.co/1GLcRq1O13', 'When each of us learns to appreciate the critical importance of ethics and makes inner values like compassion and p… https://t.co/2N48cruRKM', 'In today’s materialistic world there is a risk of people becoming slaves to money, as though they were simply cogs… https://t.co/uz9vqPlULu', 'Watch "Compassion and the Role of Women" - HHDL\'s remarks to a group of women about their role in promoting human v… https://t.co/E424tZwYCU', 'Watch Live: Mind &amp; Life Dialogue “Reimagining Human Flourishing” from Dharamsala, India on March 12-16. HHDL will e… https://t.co/hc6JyKfFRB', 'Peace has a great deal to do with warm-heartedness and respect for the lives of others, avoiding doing them harm an… https://t.co/LSrBjonqut', 'Insofar as the destructive effects of anger and hateful thoughts are concerned, one cannot get protection from weal… https://t.co/iNGWETo3Qv', 'Because of the great differences in our ways of thinking, it is inevitable that we have different religions and fai… https://t.co/tjM74upGNj', 'Practicing compassion, caring for others and sharing their problems, lays the foundation for a meaningful life, not… https://t.co/uxCctovIlU', 'The very purpose of spirituality is self-discipline. Rather than criticizing others, we should evaluate and critici… https://t.co/ivBKZxq8QN', 'Genuine friends, are attracted by a warm heart, not money, not power. A genuine friend considers you as just anothe… https://t.co/IP1mpblTTQ', 'Compassion suits our physical condition, whereas anger, fear and distrust are harmful to our well-being. Therefore,… https://t.co/ySHNbQYUwq', 'Although I am a Buddhist monk, I am skeptical that prayers alone will achieve world peace. We need instead to be en… https://t.co/xCakNIjXUW', 'I believe the ultimate source of blessings is within us. A good motivation and honesty bring self-confidence, which… https://t.co/OmPoNeglAp', 'The basic foundation of humanity is compassion and love. This is why, if even a few individuals simply try to creat… https://t.co/Sj7sips8Iu', 'Many people think that patience is a sign of weakness. I think this is a mistake. It is anger that is a sign of wea… https://t.co/nK1iUsAhbr', 'Developing inner values is much like physical exercise. The more we train our abilities, the stronger they become.… https://t.co/ffCFC6YxcV', 'What’s past is past, nothing can change that. But the future can be different if we choose to make it so. We have t… https://t.co/Gxr1vBfD7v', 'Destructive thoughts and emotions undermine the very causes of peace and happiness. If you think clearly about it,… https://t.co/pkGXYbHUKz', 'Modern education pays little attention to inner values and yet our basic human nature is compassionate. We need to… https://t.co/XUTgOYBd9l']
