# %%
import pandas as pd
import numpy as np
import os

# %%
# CSV file
csvfile = "demographics.csv"

# %%
# Read CSV file into a pandas DataFrame
### BEGIN SOLUTION
df = pd.read_csv(csvfile, dtype=object)
### END SOLUTION

# %%
# Use `dropna` to drop any rows where there is missing data
### BEGIN SOLUTION
df = df.dropna(axis=0)
### END SOLUTION

# %%
# Drop the `name` column and reset the index
### BEGIN SOLUTION
df.drop(['name'], axis=1).reset_index(drop=True)
### END SOLUTION
# Out:
#       id age height_meter weight_kg children                occupation  \
# 0      0  58         1.87        53        1             Choreographer
# 1      1  65         1.80        40        0                 Cellarman
# 2      2  32         1.80        73        1        Veterinary Surgeon
# 3      3  61         1.79        89        0                    Hawker
# 4      4  23         1.64        51        2             Choreographer
# 5      5  20         1.68        60        4         Medical Physicist
# 6      6  31         1.56        62        0                    Weaver
# 7      7  56         1.60        42        0         Lighthouse Keeper
# 8      8  30         1.62        44        3                Millwright
# 9      9  44         1.69        51        5          Medical Supplier
# 10    10  55         1.82        72        5                Manicurist
# 11    11  66         1.63        78        5            Window Dresser
# 12    12  62         1.88        41        1                 Assistant
# 13    13  35         1.53        74        5                 Paramedic
# 14    14  66         1.94        79        3               Genealogist
# 15    15  23         1.87        72        2                   Servant
# 16    16  40         1.61        46        4         Technical Liaison
# 17    17  34         1.55        78        1                 Scientist
# 18    18  64         1.69        67        4           Market Research
# 19    19  25         1.86        81        4          Medical Supplier
# 20    20  53         1.65        48        3                     Actor
# 21    21  41         1.75        49        4           Claims Adjustor
# 22    22  63         1.82        76        1                     Groom
# 23    23  60         1.98        71        0         Payroll Assistant
# 24    24  23         1.96        89        2          Machine Operator
# 25    25  42         1.78        43        0               Tea Blender
# 26    26  58         1.56        80        3                    Warden
# 27    27  41         1.94        65        1                Undertaker
# 28    28  60         1.66        80        5              Psychiatrist
# 29    29  56         1.56        52        0       Planning Technician
# ..   ...  ..          ...       ...      ...                       ...
# 970  970  67         1.92        43        2              Stone Sawyer
# 971  971  33         1.88        85        2     Applications Engineer
# 972  972  60         1.95        58        1                Instructor
# 973  973  44         1.66        66        5                  Engineer
# 974  974  21         1.64        38        4  Word Processing Operator
# 975  975  65         1.77        73        2            Metal Polisher
# 976  976  53         1.62        42        2           Plant Attendant
# 977  977  40         1.57        68        5              Betting Shop
# 978  978  51         1.54        63        1                    Slater
# 979  979  44         1.67        50        5                 Tunneller
# 980  980  42         1.57        90        5                  Storeman
# 981  981  48         1.84        83        3                 Stud Hand
# 982  982  37         1.93        77        2        Production Planner
# 983  983  47         1.96        59        2      Sports Administrator
# 984  984  44         1.74        60        3             Steel Erector
# 985  985  51         1.67        74        1                     Tiler
# 986  986  33         1.86        44        2       Wholesale Newspaper
# 987  987  39         1.65        67        3            Safety Officer
# 988  988  46         1.58        68        3        Building Estimator
# 989  989  52         1.85        65        3       Plastics Consultant
# 990  990  21         1.83        42        5                Tea Taster
# 991  991  61         1.78        90        3           Hospital Doctor
# 992  992  20         1.80        81        4      Purchasing Assistant
# 993  993  66         1.83        43        1            Garage Manager
# 994  994  31         1.57        47        3              Trichologist
# 995  995  39         1.79        50        1         Partition Erector
# 996  996  31         1.97        65        5          Playgroup Leader
# 997  997  65         1.99        63        1             Nursery Nurse
# 998  998  33         1.77        41        0  Word Processing Operator
# 999  999  63         1.64        39        1                  Shepherd
#
#     academic_degree salary       location
# 0               PhD     68   South Dakota
# 1          Bachelor     73       Delaware
# 2            Master     69   South Dakota
# 3               PhD     88      Louisiana
# 4          Bachelor     83  West Virginia
# 5          Bachelor     65   South Dakota
# 6            Master     72      Louisiana
# 7            Master     65      Louisiana
# 8            Master     87      Louisiana
# 9               PhD     72  West Virginia
# 10         Bachelor     73   South Dakota
# 11         Bachelor     90       Delaware
# 12           Master     78         Alaska
# 13         Bachelor     69       Delaware
# 14           Master     75   South Dakota
# 15              PhD     77   South Dakota
# 16         Bachelor     76      Louisiana
# 17              PhD     90   South Dakota
# 18              PhD     79      Louisiana
# 19              PhD     77   South Dakota
# 20              PhD     74      Louisiana
# 21              PhD     83       Delaware
# 22           Master     67   South Dakota
# 23           Master     72         Alaska
# 24         Bachelor     72   South Dakota
# 25         Bachelor     73  West Virginia
# 26         Bachelor     76       Delaware
# 27              PhD     76       Delaware
# 28           Master     73   South Dakota
# 29         Bachelor     85       Delaware
# ..              ...    ...            ...
# 970        Bachelor     86         Alaska
# 971             PhD     74       Delaware
# 972          Master     81       Delaware
# 973          Master     74         Alaska
# 974             PhD     82      Louisiana
# 975        Bachelor     70  West Virginia
# 976             PhD     80   South Dakota
# 977        Bachelor     85  West Virginia
# 978             PhD     75  West Virginia
# 979        Bachelor     69         Alaska
# 980        Bachelor     70      Louisiana
# 981        Bachelor     72       Delaware
# 982          Master     87       Delaware
# 983          Master     66      Louisiana
# 984        Bachelor     78      Louisiana
# 985        Bachelor     69  West Virginia
# 986             PhD     73       Delaware
# 987        Bachelor     85   South Dakota
# 988          Master     76   South Dakota
# 989             PhD     88       Delaware
# 990        Bachelor     73  West Virginia
# 991          Master     84      Louisiana
# 992          Master     67       Delaware
# 993             PhD     83      Louisiana
# 994          Master     80       Delaware
# 995          Master     74   South Dakota
# 996        Bachelor     71   South Dakota
# 997        Bachelor     89  West Virginia
# 998          Master     87      Louisiana
# 999             PhD     71  West Virginia
#
# [1000 rows x 9 columns]

# %%
# Save the cleaned data to a file called `cleaned_demographics.csv`
### BEGIN SOLUTION
clean_data = "cleaned_csv.csv"
df.to_csv(clean_data, index=False)
### END SOLUTION

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float

# %%
# Create an engine to a database file called `demographics.sqlite`
### BEGIN SOLUTION
engine = create_engine("sqlite:///demographics.sqlite")
### END SOLUTION

# %%
# Create a connection to the engine called `conn`
### BEGIN SOLUTION
conn = engine.connect()
### END SOLUTION

# %%
# Use `declarative_base` from SQLAlchemy to model the demographics table as an ORM class
# Make sure to specify types for each column
### BEGIN SOLUTION

Base = declarative_base()

class Demographics(Base):
    __tablename__ = 'demographics'

    id = Column(Integer, primary_key=True)
    age = Column(Integer)
    name = Column(Text)
    height_meter = Column(Float)
    weight_kg = Column(Float)
    children = Column(Integer)
    occupation = Column(Text)
    academic_degree = Column(Text)
    salary = Column(Integer)
    location = Column(Text)

    def __repr__(self):
        return f"id={self.id}, name={self.name}"
### END SOLUTION
# Out:
#   File "<ipython-input-12-47e105baf1d7>", line 22
#     return f"id={self.id}, name={self.name}"
#                                            ^
# SyntaxError: invalid syntax

# %%
# Use `create_all` to create the demographics table in the database
### BEGIN SOLUTION
Base.metadata.create_all(engine)
### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f89147738aed> in <module>()
#       1 # Use `create_all` to create the demographics table in the database
#       2 ### BEGIN SOLUTION
# ----> 3 Base.metadata.create_all(engine)
#       4 ### END SOLUTION
#
# NameError: name 'Base' is not defined

# %%
# Load the cleaned csv file into a pandas dataframe
### BEGIN SOLUTION
df_of_data_to_insert = pd.read_csv(clean_data)
### END SOLUTION

# %%
# Use Orient='records' to create a list of data to write
# http://pandas-docs.github.io/pandas-docs-travis/io.html#orient-options
### BEGIN SOLUTION
data = df_of_data_to_insert.to_dict(orient='records')
data[0]
### END SOLUTION
# Out:
# {'academic_degree': 'PhD',
#  'age': 58,
#  'children': 1,
#  'height_meter': 1.87,
#  'id': 0,
#  'location': 'South Dakota',
#  'name': 'Darlena Avila',
#  'occupation': 'Choreographer',
#  'salary': 68,
#  'weight_kg': 53}

# %%
# Use MetaData from SQLAlchemy to reflect the tables
### BEGIN SOLUTION
metadata = MetaData(bind=engine)
metadata.reflect()
### END SOLUTION

# %%
# Save the reference to the `demographics` table as a variable called `table`
### BEGIN SOLUTION
table = sqlalchemy.Table('demographics', metadata, autoload=True)
### END SOLUTION

# %%
# Use `table.delete()` to remove any existing data.
# Note that this is a convenience function so that you can re-run the example code multiple times.
# You would not likely do this step in production.
### BEGIN SOLUTION
conn.execute(table.delete())
### END SOLUTION

# %%
# Use `table.insert()` to insert the data into the table
### BEGIN SOLUTION
conn.execute(table.insert(), data)
### END SOLUTION

# %%
# Test that the insert works by fetching the first 5 rows. 
conn.execute("select * from demographics limit 5").fetchall()
# Out:
# [(0, 58, 'Darlena Avila', 1.87, 53.0, 1, 'Choreographer', 'PhD', 68, 'South Dakota'),
#  (1, 65, 'Yan Boyd', 1.8, 40.0, 0, 'Cellarman', 'Bachelor', 73, 'Delaware'),
#  (2, 32, 'Joette Lane', 1.8, 73.0, 1, 'Veterinary Surgeon', 'Master', 69, 'South Dakota'),
#  (3, 61, 'Jazmine Hunt', 1.79, 89.0, 0, 'Hawker', 'PhD', 88, 'Louisiana'),
#  (4, 23, 'Remedios Gomez', 1.64, 51.0, 2, 'Choreographer', 'Bachelor', 83, 'West Virginia')]

# %%
# Optional - Clean Intermediate Files
os.remove(clean_data)

# %%
# Run this line to remove the sqlite db file to clear the cache.
# !rm demographics.sqlite

# %%
# !ls
