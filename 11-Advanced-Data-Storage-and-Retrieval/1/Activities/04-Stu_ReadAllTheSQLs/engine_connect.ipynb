# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql+pymysql://root:123456789@localhost:3306/sakila")
conn = engine.connect()
# Out:
# C:\Users\KenJ\Anaconda3\lib\site-packages\pymysql\cursors.py:165: Warning: (1366, '')
#   result = self._query(query)

# %%
data = pd.read_sql("select * from film", conn)
data.head(10)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
# 5        6      AGENT TRUMAN
# 6        7   AIRPLANE SIERRA
# 7        8   AIRPORT POLLOCK
# 8        9     ALABAMA DEVIL
# 9       10  ALADDIN CALENDAR
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
# 5  A Intrepid Panorama of a Robot And a Boy who m...          2006
# 6  A Touching Saga of a Hunter And a Butler who m...          2006
# 7  A Epic Tale of a Moose And a Girl who must Con...          2006
# ...

# %%
title_data=data[['title', 'release_year']]
title_data.head(100)
# Out:
#                    title  release_year
# 0       ACADEMY DINOSAUR          2006
# 1         ACE GOLDFINGER          2006
# 2       ADAPTATION HOLES          2006
# 3       AFFAIR PREJUDICE          2006
# 4            AFRICAN EGG          2006
# 5           AGENT TRUMAN          2006
# 6        AIRPLANE SIERRA          2006
# 7        AIRPORT POLLOCK          2006
# 8          ALABAMA DEVIL          2006
# 9       ALADDIN CALENDAR          2006
# 10       ALAMO VIDEOTAPE          2006
# 11        ALASKA PHANTOM          2006
# 12           ALI FOREVER          2006
# 13        ALICE FANTASIA          2006
# 14          ALIEN CENTER          2006
# 15       ALLEY EVOLUTION          2006
# 16            ALONE TRIP          2006
# 17         ALTER VICTORY          2006
# 18          AMADEUS HOLY          2006
# 19   AMELIE HELLFIGHTERS          2006
# 20       AMERICAN CIRCUS          2006
# 21     AMISTAD MIDSUMMER          2006
# 22  ANACONDA CONFESSIONS          2006
# ...

# %%
title_data.groupby('release_year').count()
# Out:
#               title
# release_year
# 2006           1000
